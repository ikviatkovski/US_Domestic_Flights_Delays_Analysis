# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 5000)
pd.options.display.max_rows = 4000

# %%
data_total = pd.read_csv('~/ga/projects/capstone_data/data/total.csv')

# %%
data_total.head()
# Out:
#    ITIN_ID     MKT_ID  SEQ_NUM  COUPONS  YEAR  ORIGIN_AIRPORT_ID  \
# 0   201846   20184601        1        1  2018              10135
# 1   201847   20184701        1        1  2018              10135
# 2   201848   20184801        1        1  2018              10135
# 3   201849   20184901        1        1  2018              10135
# 4  2018410  201841001        1        1  2018              10135
#
#    ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  QUARTER ORIGIN  \
# 0                1013505                  30135        4    ABE
# 1                1013505                  30135        4    ABE
# 2                1013505                  30135        4    ABE
# 3                1013505                  30135        4    ABE
# 4                1013505                  30135        4    ABE
#
#   ORIGIN_COUNTRY  ORIGIN_STATE_FIPS ORIGIN_STATE_ABR ORIGIN_STATE_NM  \
# 0             US                 42               PA    Pennsylvania
# ...

# %%
data_total.columns
# Out:
# Index(['ITIN_ID', 'MKT_ID', 'SEQ_NUM', 'COUPONS', 'YEAR', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'QUARTER', 'ORIGIN',
#        'ORIGIN_COUNTRY', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_ABR',
#        'ORIGIN_STATE_NM', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST', 'DEST_COUNTRY',
#        'DEST_STATE_FIPS', 'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEST_WAC',
#        'TRIP_BREAK', 'COUPON_TYPE', 'TICKET_CARRIER', 'OPERATING_CARRIER',
#        'REPORTING_CARRIER', 'PASSENGERS', 'FARE_CLASS', 'DISTANCE',
#        'DISTANCE_GROUP', 'GATEWAY', 'ITIN_GEO_TYPE', 'COUPON_GEO_TYPE',
#        'Unnamed: 36'],
#       dtype='object')

# %%
data_total = data_total[['ORIGIN', 'ORIGIN_STATE_ABR','DEST',  'DEST_STATE_ABR','TICKET_CARRIER', 'OPERATING_CARRIER',
       'REPORTING_CARRIER', 'PASSENGERS','DISTANCE']]

# %%
new_columns = [column.lower() for column in data_total.columns]
data_total.columns = new_columns

# %%
data_total.head()
# Out:
#   origin origin_state_abr dest dest_state_abr ticket_carrier  \
# 0    ABE               PA  ATL             GA             DL
# 1    ABE               PA  ATL             GA             DL
# 2    ABE               PA  ATL             GA             DL
# 3    ABE               PA  ATL             GA             DL
# 4    ABE               PA  ATL             GA             DL
#
#   operating_carrier reporting_carrier  passengers  distance
# 0                9E                9E         1.0     692.0
# 1                9E                9E         1.0     692.0
# 2                9E                9E         3.0     692.0
# 3                9E                9E         1.0     692.0
# 4                9E                9E         1.0     692.0

# %%
data_total.shape
# Out:
# (10794583, 9)

# %%
data_oct = pd.read_csv('~/ga/projects/capstone_data/data/october.csv')
# Out:
# /Users/ilyakvyatkovskiy/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_oct.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2018        4     10             1            1  2018-10-01
# 1  2018        4     10             1            1  2018-10-01
# 2  2018        4     10             1            1  2018-10-01
# 3  2018        4     10             1            1  2018-10-01
# 4  2018        4     10             1            1  2018-10-01
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                WN                  19393         WN   N221WN
# 1                WN                  19393         WN   N8329B
# 2                WN                  19393         WN   N920WN
# 3                WN                  19393         WN   N480WN
# 4                WN                  19393         WN   N227WN
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0                802              10140                1014005
# 1               3744              10140                1014005
# ...

# %%
data_oct.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM',
#        ...
#        'DIV4_TAIL_NUM', 'DIV5_AIRPORT', 'DIV5_AIRPORT_ID',
#        'DIV5_AIRPORT_SEQ_ID', 'DIV5_WHEELS_ON', 'DIV5_TOTAL_GTIME',
#        'DIV5_LONGEST_GTIME', 'DIV5_WHEELS_OFF', 'DIV5_TAIL_NUM',
#        'Unnamed: 109'],
#       dtype='object', length=110)

# %%
data_oct.shape
# Out:
# (616101, 110)

# %%
data_oct['CANCELLED'].value_counts()
# Out:
# 0.0    611616
# 1.0      4485
# Name: CANCELLED, dtype: int64

# %%
data_oct['DIVERTED'].value_counts()
# Out:
# 0.0    614819
# 1.0      1282
# Name: DIVERTED, dtype: int64

# %%
data_oct['FLIGHTS'].value_counts()
# Out:
# 1.0    616101
# Name: FLIGHTS, dtype: int64

# %%
data_oct['CARRIER_DELAY'].value_counts()
# Out:
# 0.0       54028
# 1.0        1960
# 2.0        1889
# 3.0        1809
# 6.0        1743
# 4.0        1734
# 5.0        1632
# 7.0        1559
# 8.0        1419
# 15.0       1269
# 9.0        1258
# 10.0       1156
# 16.0       1154
# 11.0       1056
# 17.0       1043
# 18.0       1000
# 12.0        996
# 19.0        976
# 14.0        955
# 13.0        945
# 20.0        879
# 21.0        743
# 22.0        731
# 23.0        683
# 24.0        616
# 26.0        607
# 25.0        544
# 27.0        539
# 29.0        484
# 30.0        468
# 28.0        461
# 32.0        415
# 31.0        399
# 33.0        393
# 35.0        374
# 34.0        362
# 36.0        352
# 38.0        335
# 37.0        327
# 39.0        317
# 41.0        295
# 40.0        288
# 44.0        274
# 43.0        250
# 42.0        238
# 46.0        234
# 47.0        234
# 45.0        224
# 48.0        219
# 49.0        199
# 53.0        196
# 50.0        181
# 54.0        175
# 55.0        173
# 52.0        168
# ...

# %%
data_oct['DIV_AIRPORT_LANDINGS'].value_counts()
# Out:
# 0    614762
# 1      1270
# 9        57
# 2        12
# Name: DIV_AIRPORT_LANDINGS, dtype: int64

# %%
data_oct['DIV_REACHED_DEST'].value_counts()
# Out:
# 1.0    1137
# 0.0     145
# Name: DIV_REACHED_DEST, dtype: int64

# %%
data_oct['ARR_DEL15'].value_counts()
# Out:
# 0.0    508677
# 1.0    101657
# Name: ARR_DEL15, dtype: int64

# %%
data_nov = pd.read_csv('~/ga/projects/capstone_data/data/november.csv')
# Out:
# /Users/ilyakvyatkovskiy/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_dec = pd.read_csv('~/ga/projects/capstone_data/data/december.csv')

# %%
data_nov.shape
# Out:
# (586178, 110)

# %%
data_dec.shape
# Out:
# (593842, 110)

# %%
data_oct.shape[0]+data_nov.shape[0]+data_dec.shape[0]
# Out:
# 1796121

# %%
data_oct['OP_CARRIER'].value_counts()
# Out:
# WN    114663
# DL     82134
# AA     78963
# OO     66562
# UA     55565
# YX     26882
# MQ     26147
# B6     24923
# OH     23969
# AS     21634
# 9E     20943
# YV     19306
# EV     15358
# NK     13780
# F9     10516
# G4      7597
# HA      7159
# Name: OP_CARRIER, dtype: int64

# %%
delays = pd.concat([data_oct,data_nov,data_dec])
